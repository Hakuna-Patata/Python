# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from http import HTTPStatus
from pprint import pprint as pp
from datetime import datetime, date, timezone
import re

# %%
mlb_today_url = r'https://www.espn.com/mlb/schedule'

s = requests.Session()
r = s.get(mlb_today_url, timeout=10)

print(f"Connection status: {HTTPStatus(r.status_code).phrase}")
# Out:
# Connection status: OK

# %%
soup = BeautifulSoup(r.text, 'lxml')

matchups = []

for day in soup.findAll("div", {"class":"ScheduleTables mb5 ScheduleTables--mlb ScheduleTables--baseball"}):
    try:
        dt = datetime.strptime(day.find("div", {"class":"Table__Title"}).text.strip(), "%A, %B %d, %Y").date()
    except:
        dt = pd.NaT

    for match in day.findAll("td", {"class":["date__col Table__TD","teams__col Table__TD"]}):
        try:
            url_find = match.find("a")['href']
            if bool(re.search(r"/mlb/game", url_find)):
                game_url = r"https://www.espn.com" + url_find
                game_row = (dt, game_url)
                matchups.append(game_row)
            else:
                continue
        except:
            continue
    
matchup_df = pd.DataFrame(matchups, columns=['MATCH_DATE','GAME_URL'])

matchup_df.head()
# Out:
#    MATCH_DATE                                        GAME_URL
# 0  2022-05-20  https://www.espn.com/mlb/game?gameId=401354814
# 1  2022-05-20  https://www.espn.com/mlb/game?gameId=401354825
# 2  2022-05-20  https://www.espn.com/mlb/game?gameId=401354815
# 3  2022-05-20  https://www.espn.com/mlb/game?gameId=401354819
# 4  2022-05-20  https://www.espn.com/mlb/game?gameId=401354826

# %%
# test_url = r'https://www.espn.com/mlb/game?gameId=401439775'

# test_s = requests.Session()
# test_r = s.get(test_url, timeout=10)

# test_soup = BeautifulSoup(test_r.text, 'lxml')

# probable_pitchers = []

# live_prev_starting_pitchers = [pitchers.a['href'] for pitchers in test_soup.findAll("table", {"data-type":"pitching"})]

# for pitchers in test_soup.findAll("div", {"class":"pitchers__player_stats"}):
#     pitcher_name = pitchers.find("span", {"class":"fullName"}).text
#     if pitcher_name == "Undecided":
#         probable_pitchers.append("TBD")
#     else:
#         probable_pitchers.append(pitchers.a["href"])

# len(probable_pitchers)
# Out:
# 2

# %%
def get_game_pitchers_url(soup):
    probable_pitchers = []

    live_prev_starting_pitchers = [pitchers.a['href'] for pitchers in soup.findAll("table", {"data-type":"pitching"})]
    for pitchers in soup.findAll("div", {"class":"pitchers__player_stats"}):
        pitcher_name = pitchers.find("span", {"class":"fullName"}).text
        if pitcher_name == "Undecided":
            probable_pitchers.append("TBD")
        else:
            probable_pitchers.append(pitchers.a["href"])

    if len(live_prev_starting_pitchers) > 0:
        away_pitcher = live_prev_starting_pitchers[0]
        home_pitcher = live_prev_starting_pitchers[1]
    elif len(probable_pitchers) > 0:
        away_pitcher = probable_pitchers[0]
        home_pitcher = probable_pitchers[1]
    else:
        away_pitcher = np.nan
        home_pitcher = np.nan

    return (away_pitcher, home_pitcher)

# %%
def get_game_teams_url(soup):
    teams = [r"https://www.espn.com" + team.a['href'] for team in soup.findAll("div", {"class":"team-info-wrapper"})]

    if len(teams) > 0:
        away_team = teams[0]
        home_team = teams[1]
    else:
        away_team = np.nan
        home_team = np.nan

    return (away_team, home_team)

# %%
def get_game_time(soup):
    utc_dttm_str = soup.find("div", {"class":"game-date-time"}).find("span")['data-date']
    utc_dttm = datetime.strptime(utc_dttm_str, "%Y-%m-%dT%H:%MZ")
    local_dttm = utc_dttm.replace(tzinfo=timezone.utc).astimezone(tz=None)
    local_dttm = pd.NaT if local_dttm is None else local_dttm
    return tuple([local_dttm])

# %%
def get_game_stadium(soup):
    return tuple( [re.sub( r'\W+\W', '', soup.find("div", {"class":"game-field"}).text )] )

# %%
def get_game_line(soup):
    return tuple( [soup.find("div", {"class":"odds-lines-plus-logo"}).li.text] )

# %%
def get_game_info(game_url):
    try:
        s = requests.Session()
        r = s.get(game_url, timeout=10)

        soup = BeautifulSoup(r.text, 'lxml')

        game_pitchers_url = get_game_pitchers_url(soup)
        game_teams_url = get_game_teams_url(soup)
        game_time = get_game_time(soup)
        game_stadium = get_game_stadium(soup)
        game_line = get_game_line(soup)

        return game_pitchers_url + game_teams_url + game_time + game_stadium + game_line

    except:
        return (np.nan, np.nan, np.nan, np.nan, pd.NaT, np.nan, np.nan)

# %%
matchup_df = pd.concat(
    [
        matchup_df
        , pd.DataFrame(
            list(matchup_df["GAME_URL"].apply(get_game_info))
            , columns=["AWAY_PITCHER_URL","HOME_PITCHER_URL","AWAY_TEAM_URL","HOME_TEAM_URL","MATCH_DTTM","STADIUM","GAME_LINE"]
        )
    ]
    , axis="columns"
)

# %%
matchup_df
# Out:
#     MATCH_DATE                                        GAME_URL  \
# 0   2022-05-20  https://www.espn.com/mlb/game?gameId=401354814
# 1   2022-05-20  https://www.espn.com/mlb/game?gameId=401354825
# 2   2022-05-20  https://www.espn.com/mlb/game?gameId=401354815
# 3   2022-05-20  https://www.espn.com/mlb/game?gameId=401354819
# 4   2022-05-20  https://www.espn.com/mlb/game?gameId=401354826
# 5   2022-05-20  https://www.espn.com/mlb/game?gameId=401354817
# 6   2022-05-20  https://www.espn.com/mlb/game?gameId=401354818
# 7   2022-05-20  https://www.espn.com/mlb/game?gameId=401354824
# 8   2022-05-20  https://www.espn.com/mlb/game?gameId=401354820
# 9   2022-05-20  https://www.espn.com/mlb/game?gameId=401354827
# 10  2022-05-20  https://www.espn.com/mlb/game?gameId=401354828
# 11  2022-05-20  https://www.espn.com/mlb/game?gameId=401354822
# 12  2022-05-20  https://www.espn.com/mlb/game?gameId=401354823
# 13  2022-05-20  https://www.espn.com/mlb/game?gameId=401354816
# 14  2022-05-20  https://www.espn.com/mlb/game?gameId=401354821
# 15  2022-05-21  https://www.espn.com/mlb/game?gameId=401354831
# 16  2022-05-21  https://www.espn.com/mlb/game?gameId=401354829
# 17  2022-05-21  https://www.espn.com/mlb/game?gameId=401354832
# 18  2022-05-21  https://www.espn.com/mlb/game?gameId=401439775
# 19  2022-05-21  https://www.espn.com/mlb/game?gameId=401354838
# 20  2022-05-21  https://www.espn.com/mlb/game?gameId=401354839
# 26  https://www.espn.com/mlb/player/_/id/42450
# 27  https://www.espn.com/mlb/player/_/id/33203
# 28  https://www.espn.com/mlb/player/_/id/31313
# 29                                         NaN
# 30  https://www.espn.com/mlb/player/_/id/33249
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
#
#                                 HOME_PITCHER_URL  \
# 0     https://www.espn.com/mlb/player/_/id/33173
# 1     https://www.espn.com/mlb/player/_/id/40761
# 2     https://www.espn.com/mlb/player/_/id/39640
# 3     https://www.espn.com/mlb/player/_/id/39817
# 4   https://www.espn.com/mlb/player/_/id/4717904
# 5     https://www.espn.com/mlb/player/_/id/32582
# 6     https://www.espn.com/mlb/player/_/id/40934
# 7     https://www.espn.com/mlb/player/_/id/32640
# 8     https://www.espn.com/mlb/player/_/id/41227
# 9     https://www.espn.com/mlb/player/_/id/41261
# 10    https://www.espn.com/mlb/player/_/id/39915
# 11  https://www.espn.com/mlb/player/_/id/4413990
# 12    https://www.espn.com/mlb/player/_/id/36056
# 13                                           NaN
# 14                                           NaN
# 15    https://www.espn.com/mlb/player/_/id/33263
# 16    https://www.espn.com/mlb/player/_/id/41022
# 17    https://www.espn.com/mlb/player/_/id/42436
# 18                                           NaN
# 19    https://www.espn.com/mlb/player/_/id/33696
# 20    https://www.espn.com/mlb/player/_/id/39674
# 21                                           NaN
# 22    https://www.espn.com/mlb/player/_/id/39836
# 23    https://www.espn.com/mlb/player/_/id/40912
# 24    https://www.espn.com/mlb/player/_/id/32106
# 25  https://www.espn.com/mlb/player/_/id/4311625
# 26    https://www.espn.com/mlb/player/_/id/35292
# 27     https://www.espn.com/mlb/player/_/id/6341
# 28    https://www.espn.com/mlb/player/_/id/37515
# 29                                           NaN
# 30    https://www.espn.com/mlb/player/_/id/33252
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                                           NaN
# 39                                           NaN
# 40                                           NaN
# 41                                           NaN
# 42                                           NaN
# 43                                           NaN
# 44                                           NaN
# 45                                           NaN
# 46                                           NaN
#
#                                         AWAY_TEAM_URL  \
# 0   https://www.espn.com/mlb/team/_/name/ari/arizo...
# 1   https://www.espn.com/mlb/team/_/name/stl/st-lo...
# 2   https://www.espn.com/mlb/team/_/name/atl/atlan...
# 3   https://www.espn.com/mlb/team/_/name/lad/los-a...
# 4   https://www.espn.com/mlb/team/_/name/tb/tampa-...
# 5   https://www.espn.com/mlb/team/_/name/cin/cinci...
# 6   https://www.espn.com/mlb/team/_/name/det/detro...
# 7   https://www.espn.com/mlb/team/_/name/sea/seatt...
# 8   https://www.espn.com/mlb/team/_/name/min/minne...
# 9   https://www.espn.com/mlb/team/_/name/tex/texas...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
#
#                   MATCH_DTTM                           STADIUM       GAME_LINE
# 0  2022-05-20 13:20:00-05:00                     Wrigley Field  Line: CHC -145
# 1  2022-05-20 17:35:00-05:00          PNC ParkCoverageApple TV  Line: STL -150
# 2  2022-05-20 17:40:00-05:00                    loanDepot park  Line: ATL -120
# 3  2022-05-20 18:05:00-05:00    Citizens Bank ParkCoverageESPN  Line: LAD -145
# 4  2022-05-20 18:05:00-05:00       Oriole Park at Camden Yards   Line: TB -135
# 5  2022-05-20 18:07:00-05:00                     Rogers Centre  Line: TOR -180
# 6  2022-05-20 18:10:00-05:00                 Progressive Field  Line: CLE -115
# 7  2022-05-20 18:10:00-05:00                       Fenway Park  Line: BOS -125
# 8  2022-05-20 19:10:00-05:00                  Kauffman Stadium  Line: MIN -130
# 9  2022-05-20 19:10:00-05:00  Minute Maid ParkCoverageApple TV  Line: HOU -175
# 10 2022-05-20 19:10:00-05:00             American Family Field  Line: MIL -210
# 11 2022-05-20 20:38:00-05:00                     Angel Stadium  Line: LAA -185
# 12 2022-05-20 21:15:00-05:00                       Oracle Park   Line: SF -120
# 13 2022-05-20 18:05:00-05:00                    Yankee Stadium  Line: NYY -215
# 14 2022-05-20 19:40:00-05:00                       Coors Field  Line: NYM -125
# 15 2022-05-21 12:05:00-05:00        Yankee StadiumCoverageESPN  Line: NYY -185
# 16 2022-05-21 13:20:00-05:00                     Wrigley Field  Line: CHC -140
# 17 2022-05-21 14:07:00-05:00                     Rogers Centre  Line: TOR -245
# 18                       NaT                               NaN             NaN
# 19 2022-05-21 15:05:00-05:00            Oracle ParkCoverageFS1   Line: SF -140
# 20 2022-05-21 15:10:00-05:00                       Fenway Park  Line: BOS -145
# 21                       NaT                               NaN             NaN
# 22 2022-05-21 17:10:00-05:00                    loanDepot park  Line: ATL -130
# 23 2022-05-21 17:10:00-05:00                 Progressive Field  Line: CLE -185
# 24 2022-05-21 17:35:00-05:00                          PNC Park  Line: STL -135
# 25 2022-05-21 18:05:00-05:00       Oriole Park at Camden Yards   Line: TB -150
# 26 2022-05-21 18:10:00-05:00                  Kauffman Stadium  Line: MIN -150
# 27 2022-05-21 18:10:00-05:00                  Minute Maid Park  Line: HOU -245
# 28 2022-05-21 18:10:00-05:00             American Family Field  Line: MIL -200
# 29                       NaT                               NaN             NaN
# 30 2022-05-21 20:07:00-05:00          Angel StadiumCoverageFS1  Line: LAA -160
# 31                       NaT                               NaN             NaN
# 32                       NaT                               NaN             NaN
# 33                       NaT                               NaN             NaN
# 34                       NaT                               NaN             NaN
# 35                       NaT                               NaN             NaN
# 36                       NaT                               NaN             NaN
# 37                       NaT                               NaN             NaN
# 38                       NaT                               NaN             NaN
# 39                       NaT                               NaN             NaN
# 40                       NaT                               NaN             NaN
# 41                       NaT                               NaN             NaN
# 42                       NaT                               NaN             NaN
# 43                       NaT                               NaN             NaN
# 44                       NaT                               NaN             NaN
# 45                       NaT                               NaN             NaN
# 46                       NaT                               NaN             NaN
